# %%
import pandas as pd

# %%
df = pd.read_csv('csv_files\\train_test.csv')
df
# Out:
#     Mileage  Age(yrs)  Sell Price($)
# 0     69000         6          18000
# 1     35000         3          34000
# 2     57000         5          26100
# 3     22500         2          40000
# 4     46000         4          31500
# 5     59000         5          26750
# 6     52000         5          32000
# 7     72000         6          19300
# 8     91000         8          12000
# 9     67000         6          22000
# 10    83000         7          18700
# 11    79000         7          19500
# 12    59000         5          26000
# 13    58780         4          27500
# 14    82450         7          19400
# 15    25400         3          35000
# 16    28000         2          35500
# 17    69000         5          19700
# 18    87600         8          12800
# 19    52000         5          28200

# %%
x = df[['Mileage','Age(yrs)']]
y = df['Sell Price($)']
y
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     26750
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    18700
# 11    19500
# 12    26000
# 13    27500
# 14    19400
# 15    35000
# 16    35500
# 17    19700
# 18    12800
# 19    28200
# Name: Sell Price($), dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#     Mileage  Age(yrs)
# 5     59000         5
# 13    58780         4
# 7     72000         6
# 4     46000         4
# 15    25400         3
# 11    79000         7
# 8     91000         8
# 3     22500         2
# 0     69000         6
# 16    28000         2
# 18    87600         8
# 10    83000         7
# 1     35000         3
# 14    82450         7
# 6     52000         5
# 17    69000         5

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
plt.plot(x_train,y_train,'r .')
plt.plot(x_train,reg.predict(x_train),'g-')
# Out:
# [<matplotlib.lines.Line2D at 0x210269be360>,
#  <matplotlib.lines.Line2D at 0x2102470bd70>]

# %%
reg.predict(x_test)
# Out:
# array([27837.70240951, 26153.19745325, 25479.39547075, 22423.75007093])

# %%
reg.score(x_test,y_test)
# Out:
# 0.970951051467043

# %%
y_test
# Out:
# 19    28200
# 2     26100
# 12    26000
# 9     22000
# Name: Sell Price($), dtype: int64

# %%
reg.score(x_test,y_test)
# Out:
# 0.970951051467043
